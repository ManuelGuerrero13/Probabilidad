# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelGuerrero13/Probabilidad/blob/main/Tarea5'Unidad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #probabilidad y estadistica
# ### alumno: Manuel Guerrero Morales

# %% [markdown]
# importar libreria "statistics"

# %%
from statistics import *;

# %% [markdown]
# ##Ejemplo 1: Registro de calificaciones de 12 alumnos

# %% [markdown]
# crear un arreglo de calificaciones de un grupo e imprimirlo

# %%
grupoa = [70,70,75,100,95,45,80,73,20,96];
print(grupoa);
# Out:
# [70, 70, 75, 100, 95, 45, 80, 73, 20, 96]

# %% [markdown]
# ###Determinar la media del grupo A

# %%
print("el promedio del grupo A es",mean(grupoa));
# Out:
# el promedio del grupo A es 72.4

# %% [markdown]
# ###determinar la mediana del grupo A

# %%
print("la mediana del grupo A es",median(grupoa))
# Out:
# la mediana del grupo A es 74.0

# %% [markdown]
# ###Determinar la moda del grupo A

# %%
print("La moda del grupo A es",mode(grupoa))
# Out:
# La moda del grupo A es 70

# %% [markdown]
# ##Ejemplo 2: Tiempos de 100 metros de un grupo de alumnos

# %%
tiempos = [15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20];
print(tiempos);
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %% [markdown]
# ###funcion mean para determinar el promedio

# %%
print("el promedio de los tiempos es de:",mean(tiempos));
# Out:
# el promedio de los tiempos es de: 17.322

# %% [markdown]
# ###funcion median para calcular la mediana

# %%
print("la mediana de los tiempos es de",median(tiempos));
# Out:
# la mediana de los tiempos es de 17.2

# %% [markdown]
# funcion mode para calcular la moda

# %%
print("la moda de los tiempos es de",mode(tiempos));
# Out:
# la moda de los tiempos es de 15.1

# %% [markdown]
# funcion multimode para calcular multiples modas(por ejemplo, en caso de que sea bimodal)

# %%
print("las modas de los tiempos son de",multimode(tiempos));
# Out:
# las modas de los tiempos son de [15.1, 17.2]

# %% [markdown]
# ###Ejemplo 3: Histogramas de 2 grupos
#
#
# 1.   En este ejemplo generamos 100 numeros aleatorios reales que representa la produccion diaria de 100 telares (medidas en metros)
# 2.   Generar otra lista con la produccion de 100 telares para una segunda fabrica
# 3.   con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la moda, la media, la mediana y la desviacion estandar
# 4.   graficar un gistograma para cada fabrica

# %%
#libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
    num_Aleatorio = round(random.uniform(50,100),2);
    fabrica1.append(num_Aleatorio);
print(fabrica1);
# Out:
# [78.31, 82.16, 53.02, 76.54, 73.7, 70.17, 94.98, 64.37, 68.2, 73.66, 87.1, 85.19, 96.04, 78.57, 79.06, 54.88, 68.38, 71.79, 90.9, 86.91, 99.1, 75.67, 98.41, 59.37, 58.83, 81.91, 76.79, 85.54, 98.15, 55.43, 83.65, 64.68, 68.42, 76.86, 72.94, 86.9, 85.25, 61.85, 52.19, 68.63, 53.52, 63.02, 71.73, 87.51, 93.88, 94.76, 83.48, 94.03, 89.32, 75.41, 93.39, 90.86, 90.7, 59.83, 86.69, 80.33, 86.72, 64.54, 58.1, 85.45, 63.19, 59.18, 81.73, 75.49, 98.02, 70.32, 83.27, 68.7, 65.15, 75.03, 95.22, 90.57, 78.72, 70.06, 71.14, 85.32, 87.35, 74.25, 91.54, 91.4, 64.59, 69.51, 81.89, 51.83, 80.08, 79.33, 51.06, 54.63, 56.63, 77.95, 81.99, 68.02, 63.15, 56.52, 81.15, 65.3, 82.64, 58.41, 51.13, 97.16]

# %%
fabrica2 = []
for i in range(100):
    num_Aleatorio = round(random.uniform(50,100),2);
    fabrica2.append(num_Aleatorio);
print(fabrica2);
# Out:
# [56.36, 99.34, 50.59, 53.92, 93.74, 95.1, 60.9, 62.18, 61.31, 97.88, 73.04, 50.85, 53.22, 51.62, 75.78, 73.26, 64.92, 99.86, 68.79, 68.47, 87.54, 99.38, 87.0, 79.63, 99.85, 88.7, 83.46, 100.0, 53.5, 90.68, 80.29, 69.74, 84.45, 91.41, 91.59, 67.62, 76.14, 89.82, 93.07, 59.54, 99.64, 56.45, 69.5, 79.75, 66.66, 52.8, 52.09, 61.13, 99.5, 68.29, 80.19, 59.0, 71.59, 83.07, 93.81, 66.34, 80.12, 59.79, 73.06, 82.06, 60.44, 97.33, 64.68, 62.94, 98.72, 66.99, 57.55, 89.3, 54.3, 65.76, 93.9, 73.67, 89.37, 80.73, 53.09, 80.15, 58.96, 90.57, 52.71, 65.2, 82.78, 94.59, 65.06, 52.11, 73.54, 74.81, 95.46, 56.08, 64.58, 98.94, 99.42, 90.32, 79.01, 50.65, 74.64, 87.63, 70.84, 89.29, 90.08, 91.88]

# %%
# libreria de python para graficar valores
import matplotlib.pyplot as plt;

# %%
plt.hist(fabrica1);
plt.title("produccion de la fabrica 1");

# %%
plt.hist(fabrica2);
plt.title("produccion de la fabrica 2");

# %%
media = mean(fabrica1);
mediana = median(fabrica1);
moda = mode(fabrica1);

print("valores de la fabrica 1");
print("la media es =",media);
print("la mediana es =",mediana);
print("la moda es =",moda);
# Out:
# valores de la fabrica 1
# la media es = 75.9639
# la mediana es = 76.825
# la moda es = 78.31

# %%
media = mean(fabrica2);
mediana = median(fabrica2);
moda = mode(fabrica2);

print("valores de la fabrica 2");
print("la media es =",media);
print("la mediana es =",mediana);
print("la moda es =",moda);
# Out:
# valores de la fabrica 2
# la media es = 75.7745
# la mediana es = 74.725
# la moda es = 56.36

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas
# una al lado de la otra
fig,( ax1,ax2) = plt.subplots(nrows =1,ncols=2);

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas
# una al lado de la otra
fig,( ax1,ax2) = plt.subplots(nrows =1,ncols=2, figsize=(10,5));
ax1.hist(fabrica1);
ax2.hist(fabrica2);
plt.show();

# %%
#valor minimo, maximo, rango


media1 = mean(fabrica1);
mediana1 = median(fabrica1);
moda1 = mode(fabrica1);

# %%
plt.hist(fabrica1, bins =10, alpha=0.4,color='b',edgecolor = "black");
plt.axvline(media1, color='b',linestyle='dashed',linewidth=2,label='media');
plt.axvline(mediana1, color='r',linestyle='dashed',linewidth=2,label='mediana');
plt.axvline(moda1, color='y',linestyle='dashed',linewidth=2,label='moda');
plt.xlabel('valor');
plt.ylabel('frecuencia');
plt.title("la produccion diaria de la fabrica 1");
plt.legend()
plt.show()

# %%
#valor minimo, maximo, rango


media2 = mean(fabrica2);
mediana2 = median(fabrica2);
moda2 = mode(fabrica2);

# %%
plt.hist(fabrica2, bins =10, alpha=0.4,color='b',edgecolor = "black");
plt.axvline(media2, color='b',linestyle='dashed',linewidth=2,label='media');
plt.axvline(mediana2, color='r',linestyle='dashed',linewidth=2,label='mediana');
plt.axvline(moda2, color='y',linestyle='dashed',linewidth=2,label='moda');
plt.xlabel('valor');
plt.ylabel('frecuencia');
plt.title("la produccion diaria de la fabrica 2");
plt.legend()
plt.show()

# %% [markdown]
# #Maximo,Minimo y Rango

# %%
maximo = max(fabrica1);
minimo = min(fabrica1);
rango = maximo - minimo;
media = mean(fabrica1);
mediana = median(fabrica1);
moda = mode(fabrica1);
print("estadisticas descriptivas de la fabrica 1 \n","media =", media,
      "\n mediana =", mediana, "\n moda =", moda, "\n maximo =", maximo,
      "\n minimo =", minimo, "\n rango =", rango);
# Out:
# estadisticas descriptivas de la fabrica 1
#  media = 75.9639
#  mediana = 76.825
#  moda = 78.31
#  maximo = 99.1
#  minimo = 51.06
#  rango = 48.03999999999999

# %%
maximo2 = max(fabrica2);
minimo2 = min(fabrica2);
rango2 = maximo - minimo;
media2 = mean(fabrica2);
mediana2 = median(fabrica2);
moda2 = mode(fabrica2);
print("estadisticas descriptivas de la fabrica 2 \n","media =", media2,
      "\n mediana =", mediana2, "\n moda =", moda2, "\n maximo =", maximo2,
      "\n minimo =", minimo2, "\n rango =", rango2);
# Out:
# estadisticas descriptivas de la fabrica 2
#  media = 75.7745
#  mediana = 74.725
#  moda = 56.36
#  maximo = 100.0
#  minimo = 50.59
#  rango = 48.03999999999999

# %% [markdown]
# #Dispersion de los datos

# %%
stdev_fabrica1 = stdev(fabrica1);
print("la desviacion estandar de la fabrica 1 es =",stdev_fabrica1);
# Out:
# la desviacion estandar de la fabrica 1 es = 13.288606640823764

# %%
stdev_fabrica2 = stdev(fabrica2);
print("la desviacion estandar de la fabrica 2 es =",stdev_fabrica2);
# Out:
# la desviacion estandar de la fabrica 2 es = 15.737313593539849

# %%
plt.figure(figsize=(10,8));
plt.hist(fabrica1, bins =10, alpha=0.4,color='b',edgecolor =  "black");
plt.axvline(media1, color='b',linestyle='dashed',linewidth=2,label= f'media ={media1:2f}');
plt.axvline(mediana1, color='r',linestyle='dashed',linewidth=2,label= f'mediana ={mediana1:2f}');
plt.axvline(moda1, color='y',linestyle='dashed',linewidth=2,label=f'moda ={moda1:2f}');

plt.axvline(media1 - stdev_fabrica1, color='black',linestyle='dashed',
            linewidth=2,label=f'Desv. Estandar ={stdev_fabrica1:.2f}');
plt.axvline(media1 + stdev_fabrica1, color='black',linestyle='dashed',
            linewidth=2);

plt.xlabel('valor');
plt.ylabel('frecuencia');
plt.title("la produccion diaria de la fabrica 1");
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8));
plt.hist(fabrica2, bins =20, alpha=0.4,color='b',edgecolor =  "black");
plt.axvline(media2, color='b',linestyle='dashed',linewidth=2,label= f'media ={media2:2f}');
plt.axvline(mediana2, color='r',linestyle='dashed',linewidth=2,label= f'mediana ={mediana2:2f}');
plt.axvline(moda2, color='y',linestyle='dashed',linewidth=2,label=f'moda ={moda2:2f}');

plt.axvline(media2 - stdev_fabrica2, color='black',linestyle='dashed',
            linewidth=2,label=f'Desv. Estandar ={stdev_fabrica2:.2f}');
plt.axvline(media2 + stdev_fabrica2, color='black',linestyle='dashed',
            linewidth=2);

plt.xlabel('valor');
plt.ylabel('frecuencia');
plt.title("la produccion diaria de la fabrica 2");
plt.legend()
plt.show()

# %%
print(fabrica1);
# Out:
# [78.31, 82.16, 53.02, 76.54, 73.7, 70.17, 94.98, 64.37, 68.2, 73.66, 87.1, 85.19, 96.04, 78.57, 79.06, 54.88, 68.38, 71.79, 90.9, 86.91, 99.1, 75.67, 98.41, 59.37, 58.83, 81.91, 76.79, 85.54, 98.15, 55.43, 83.65, 64.68, 68.42, 76.86, 72.94, 86.9, 85.25, 61.85, 52.19, 68.63, 53.52, 63.02, 71.73, 87.51, 93.88, 94.76, 83.48, 94.03, 89.32, 75.41, 93.39, 90.86, 90.7, 59.83, 86.69, 80.33, 86.72, 64.54, 58.1, 85.45, 63.19, 59.18, 81.73, 75.49, 98.02, 70.32, 83.27, 68.7, 65.15, 75.03, 95.22, 90.57, 78.72, 70.06, 71.14, 85.32, 87.35, 74.25, 91.54, 91.4, 64.59, 69.51, 81.89, 51.83, 80.08, 79.33, 51.06, 54.63, 56.63, 77.95, 81.99, 68.02, 63.15, 56.52, 81.15, 65.3, 82.64, 58.41, 51.13, 97.16]

# %%
plt.boxplot(fabrica1);
plt.title("Produccion de la fabrica 1");
plt.ylabel("produccion en metros");
plt.show()

# %%
plt.boxplot(fabrica2);
plt.title("Produccion de la fabrica 2");
plt.ylabel("produccion en metros");
plt.show()

# %% [markdown]
# ##Comparamos la produccion de la fabrica 1 y 2 con un diagrama de cajas y bigotes:

# %%
fig,( ax1, ax2) = plt.subplots(nrows=1, ncols = 2, figsize = (9,4));
ax1.boxplot( fabrica1, vert = True, patch_artist=True);
ax1.set_title("produccion de la fabrica 1");
ax2.boxplot( fabrica2, vert = True, patch_artist=True);
ax2.set_title("produccion de la fabrica 2");
plt.show();

# %%
print(fabrica2);
# Out:
# [56.36, 99.34, 50.59, 53.92, 93.74, 95.1, 60.9, 62.18, 61.31, 97.88, 73.04, 50.85, 53.22, 51.62, 75.78, 73.26, 64.92, 99.86, 68.79, 68.47, 87.54, 99.38, 87.0, 79.63, 99.85, 88.7, 83.46, 100.0, 53.5, 90.68, 80.29, 69.74, 84.45, 91.41, 91.59, 67.62, 76.14, 89.82, 93.07, 59.54, 99.64, 56.45, 69.5, 79.75, 66.66, 52.8, 52.09, 61.13, 99.5, 68.29, 80.19, 59.0, 71.59, 83.07, 93.81, 66.34, 80.12, 59.79, 73.06, 82.06, 60.44, 97.33, 64.68, 62.94, 98.72, 66.99, 57.55, 89.3, 54.3, 65.76, 93.9, 73.67, 89.37, 80.73, 53.09, 80.15, 58.96, 90.57, 52.71, 65.2, 82.78, 94.59, 65.06, 52.11, 73.54, 74.81, 95.46, 56.08, 64.58, 98.94, 99.42, 90.32, 79.01, 50.65, 74.64, 87.63, 70.84, 89.29, 90.08, 91.88]

# %%
fabrica2.append(150);
print(fabrica2);
# Out:
# [56.36, 99.34, 50.59, 53.92, 93.74, 95.1, 60.9, 62.18, 61.31, 97.88, 73.04, 50.85, 53.22, 51.62, 75.78, 73.26, 64.92, 99.86, 68.79, 68.47, 87.54, 99.38, 87.0, 79.63, 99.85, 88.7, 83.46, 100.0, 53.5, 90.68, 80.29, 69.74, 84.45, 91.41, 91.59, 67.62, 76.14, 89.82, 93.07, 59.54, 99.64, 56.45, 69.5, 79.75, 66.66, 52.8, 52.09, 61.13, 99.5, 68.29, 80.19, 59.0, 71.59, 83.07, 93.81, 66.34, 80.12, 59.79, 73.06, 82.06, 60.44, 97.33, 64.68, 62.94, 98.72, 66.99, 57.55, 89.3, 54.3, 65.76, 93.9, 73.67, 89.37, 80.73, 53.09, 80.15, 58.96, 90.57, 52.71, 65.2, 82.78, 94.59, 65.06, 52.11, 73.54, 74.81, 95.46, 56.08, 64.58, 98.94, 99.42, 90.32, 79.01, 50.65, 74.64, 87.63, 70.84, 89.29, 90.08, 91.88, 150]

# %%
plt.boxplot(fabrica2);
plt.title("Produccion de la fabrica 2");
plt.ylabel("produccion en metros");
plt.show()
